# %% [markdown]
# # CUSTOM CNN without bored class

# %%
# Import the Sequential model and layers
import tensorflow as tf
from tensorflow.keras.models import Sequential, model_from_json
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dense, Flatten, Conv2D, Dropout, MaxPooling2D, BatchNormalization

from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
import splitfolders #pip installsplit-folders
if not os.path.exists('dataset3/train'):
    splitfolders.ratio('C:/Users/mysan/OneDrive/Desktop/c_data/NEW CONSTRUCTED/FINAL_CONV5/', output="dataset4", seed=1337, ratio=(0.7, 0.2, 0.1))
# Out:
# Copying files: 37100 files [02:24, 256.97 files/s]

# %%
#Total Data
datagen_d = ImageDataGenerator()
totaldata = datagen_d.flow_from_directory('C:/Users/mysan/OneDrive/Desktop/c_data/NEW CONSTRUCTED/FINAL_CONV5/')

emotion_map = {0 : 'CONFUSED', 1 : 'DELIGHT', 2 : 'FRUSTRATED', 3 : 'NEUTRAL'}
emotion_counts = pd.Series(totaldata.classes).value_counts(sort=False).reset_index()
emotion_counts.columns = ['Emotion', 'Total Value']
emotion_counts['Emotion'] = emotion_counts['Emotion'].map(emotion_map)
display(emotion_counts)

import seaborn as sns
# Plotting a bar graph of the class distributions
plt.figure(figsize=(6,4))
sns.barplot(x = "Emotion", y = "Total Value",data=emotion_counts)
plt.title('Class distribution')
plt.ylabel('Total Value', fontsize=12)
plt.xlabel('Emotions', fontsize=12)
plt.show()
# Out:
# Found 27720 images belonging to 4 classes.
#       Emotion  Total Value
# 0    CONFUSED         4690
# 1     DELIGHT         7072
# 2  FRUSTRATED         8418
# 3     NEUTRAL         7540

# %%
batch_size = 32

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   horizontal_flip = True)

val_datagen = ImageDataGenerator(rescale= 1./255)

test_datagen = ImageDataGenerator(rescale= 1./255)

# Generates batches of Augmented Image data
print("train_generator")
train_generator = train_datagen.flow_from_directory('dataset3/train/', target_size = (160, 160), 
                                                        batch_size = batch_size,
                                                        class_mode = 'sparse') 
# Generator for validation data
print("\nvalidation_generator")
validation_generator = val_datagen.flow_from_directory('dataset3/val/', 
                                                        target_size = (160, 160),
                                                        batch_size = batch_size,
                                                        class_mode = 'sparse')
# Out:
# train_generator
# Found 19403 images belonging to 4 classes.
#
# validation_generator
# Found 5543 images belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

class_names = {0 : 'CONFUSED', 1 : 'DELIGHT', 2 : 'FRUSTRATED', 3 : 'NEUTRAL'}

plt.figure(figsize=(12, 12))
for i in range(9):
    images, labels = train_generator.next()
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i])
    plt.title(class_names[labels[i]])
    plt.axis("on")

# %%
NUM_CLASSES = 4

from keras import layers


# Model
model = Sequential()
# Add convolution 2D
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu', padding="same",
        kernel_initializer='he_normal',input_shape=(160, 160, 3)),)
model.add(BatchNormalization())
model.add(Conv2D(32,kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(32,kernel_size=5,strides=2,padding='same',activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())
# Add dropouts to the model
model.add(Dropout(0.3))
model.add(Conv2D(64, kernel_size=(3, 3), strides=2,padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=(3, 3), strides=2,padding='same', activation='relu'))
# Add dropouts to the model
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
# Add dropouts to the model
model.add(Dropout(0.3))
model.add(Dense(NUM_CLASSES, activation='softmax'))

#Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 160, 160, 32)      896
#
#  batch_normalization (BatchN  (None, 160, 160, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 158, 158, 32)      9248
#
#  batch_normalization_1 (Batc  (None, 158, 158, 32)     128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 79, 79, 32)        25632
#
#  max_pooling2d (MaxPooling2D  (None, 39, 39, 32)       0
#  )
#
#  batch_normalization_2 (Batc  (None, 39, 39, 32)       128
#  hNormalization)
#
#  dropout (Dropout)           (None, 39, 39, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 10, 10, 64)       256
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 5, 5, 64)          36928
#
#  dropout_1 (Dropout)         (None, 5, 5, 64)          0
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 128)               204928
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 297,284
# Trainable params: 296,964
# Non-trainable params: 320
# _________________________________________________________________

# %%
model.compile(loss = tf.keras.losses.sparse_categorical_crossentropy, optimizer= 'adam', metrics=['accuracy'])

# %%
#Learning Rate
from keras.callbacks import ReduceLROnPlateau
lrr= ReduceLROnPlateau(monitor='val_accuracy',   factor=.01,   patience=3,  min_lr=1e-5)

# %%
#Defining the parameters
#batch_size= 100
epochs=100 #100
#learn_rate=.001

# %%
#Training the model
history = model.fit(train_generator, epochs = epochs, steps_per_epoch = len(train_generator)//batch_size, validation_data = validation_generator, callbacks = [lrr], verbose=1)
# Evaluating model performance on Testing data
loss, accuracy = model.evaluate(validation_generator)

print("\nModel's Evaluation Metrics: ")
print("---------------------------")
print("Accuracy: {:,.2f} % \nLoss: {:,.2f} %".format(accuracy*100, loss*100))

#on FINAL_CONV3
#Accuracy: 79.98 % 
#Loss: 60.64 %

#on FINAL_CONV4
#Accuracy: 86.70 % 
#Loss: 38.32 %
# Out:
# Epoch 1/100
# 25/25 [==============================] - 34s 1s/step - loss: 1.4551 - accuracy: 0.3475 - val_loss: 49.6371 - val_accuracy: 0.2033 - lr: 0.0010
# Epoch 2/100
# 25/25 [==============================] - 8s 338ms/step - loss: 1.1724 - accuracy: 0.4588 - val_loss: 9.0630 - val_accuracy: 0.2243 - lr: 0.0010
# Epoch 3/100
# 25/25 [==============================] - 8s 334ms/step - loss: 1.0536 - accuracy: 0.5475 - val_loss: 2.7933 - val_accuracy: 0.2929 - lr: 0.0010
# Epoch 4/100
# 25/25 [==============================] - 8s 334ms/step - loss: 0.9389 - accuracy: 0.6438 - val_loss: 2.5286 - val_accuracy: 0.2434 - lr: 0.0010
# Epoch 5/100
# 25/25 [==============================] - 8s 332ms/step - loss: 0.8322 - accuracy: 0.6750 - val_loss: 1.5179 - val_accuracy: 0.4139 - lr: 0.0010
# Epoch 6/100
# 25/25 [==============================] - 8s 335ms/step - loss: 0.8765 - accuracy: 0.6662 - val_loss: 1.1190 - val_accuracy: 0.5704 - lr: 0.0010
# Epoch 7/100
# 25/25 [==============================] - 8s 322ms/step - loss: 0.7992 - accuracy: 0.6938 - val_loss: 1.1519 - val_accuracy: 0.5739 - lr: 0.0010
# Epoch 8/100
# 25/25 [==============================] - 8s 318ms/step - loss: 0.8213 - accuracy: 0.6775 - val_loss: 1.6954 - val_accuracy: 0.3503 - lr: 0.0010
# Epoch 9/100
# 25/25 [==============================] - 8s 323ms/step - loss: 0.7695 - accuracy: 0.7025 - val_loss: 0.8852 - val_accuracy: 0.6700 - lr: 0.0010
# Epoch 10/100
# 25/25 [==============================] - 8s 323ms/step - loss: 0.7359 - accuracy: 0.7362 - val_loss: 0.9604 - val_accuracy: 0.6508 - lr: 0.0010
# Epoch 11/100
# 25/25 [==============================] - 8s 317ms/step - loss: 0.7337 - accuracy: 0.7163 - val_loss: 0.7233 - val_accuracy: 0.7196 - lr: 0.0010
# Epoch 12/100
# 25/25 [==============================] - 8s 322ms/step - loss: 0.6879 - accuracy: 0.7613 - val_loss: 1.0322 - val_accuracy: 0.5710 - lr: 0.0010
# Epoch 13/100
# 25/25 [==============================] - 8s 310ms/step - loss: 0.6862 - accuracy: 0.7500 - val_loss: 0.7577 - val_accuracy: 0.7076 - lr: 0.0010
# Epoch 14/100
# 25/25 [==============================] - 8s 328ms/step - loss: 0.6555 - accuracy: 0.7650 - val_loss: 0.8624 - val_accuracy: 0.6438 - lr: 0.0010
# Epoch 15/100
# 25/25 [==============================] - 7s 303ms/step - loss: 0.6390 - accuracy: 0.7675 - val_loss: 0.7639 - val_accuracy: 0.6992 - lr: 1.0000e-05
# Epoch 16/100
# 25/25 [==============================] - 8s 311ms/step - loss: 0.6123 - accuracy: 0.7812 - val_loss: 0.6739 - val_accuracy: 0.7496 - lr: 1.0000e-05
# Epoch 17/100
# 25/25 [==============================] - 8s 320ms/step - loss: 0.6044 - accuracy: 0.7975 - val_loss: 0.6446 - val_accuracy: 0.7645 - lr: 1.0000e-05
# Epoch 18/100
# 25/25 [==============================] - 8s 343ms/step - loss: 0.6422 - accuracy: 0.7575 - val_loss: 0.6198 - val_accuracy: 0.7753 - lr: 1.0000e-05
# Epoch 19/100
# 25/25 [==============================] - 9s 354ms/step - loss: 0.5872 - accuracy: 0.8050 - val_loss: 0.6120 - val_accuracy: 0.7789 - lr: 1.0000e-05
# Epoch 20/100
# 25/25 [==============================] - 8s 338ms/step - loss: 0.6245 - accuracy: 0.7775 - val_loss: 0.6035 - val_accuracy: 0.7865 - lr: 1.0000e-05
# Epoch 21/100
# 25/25 [==============================] - 7s 298ms/step - loss: 0.6151 - accuracy: 0.7887 - val_loss: 0.5996 - val_accuracy: 0.7891 - lr: 1.0000e-05
# Epoch 22/100
# 25/25 [==============================] - 8s 307ms/step - loss: 0.6275 - accuracy: 0.7750 - val_loss: 0.5994 - val_accuracy: 0.7903 - lr: 1.0000e-05
# Epoch 23/100
# 25/25 [==============================] - 7s 293ms/step - loss: 0.6236 - accuracy: 0.8000 - val_loss: 0.5958 - val_accuracy: 0.7905 - lr: 1.0000e-05
# Epoch 24/100
# 25/25 [==============================] - 7s 299ms/step - loss: 0.6340 - accuracy: 0.7738 - val_loss: 0.5906 - val_accuracy: 0.7928 - lr: 1.0000e-05
# Epoch 25/100
# 25/25 [==============================] - 7s 290ms/step - loss: 0.6027 - accuracy: 0.8000 - val_loss: 0.5873 - val_accuracy: 0.7908 - lr: 1.0000e-05
# Epoch 26/100
# 25/25 [==============================] - 7s 303ms/step - loss: 0.6056 - accuracy: 0.7763 - val_loss: 0.5863 - val_accuracy: 0.7899 - lr: 1.0000e-05
# Epoch 27/100
# 25/25 [==============================] - 7s 278ms/step - loss: 0.6031 - accuracy: 0.7887 - val_loss: 0.5822 - val_accuracy: 0.7944 - lr: 1.0000e-05
# Epoch 28/100
# 25/25 [==============================] - 7s 292ms/step - loss: 0.6321 - accuracy: 0.7800 - val_loss: 0.5787 - val_accuracy: 0.7974 - lr: 1.0000e-05
# Epoch 29/100
# 25/25 [==============================] - 7s 288ms/step - loss: 0.6190 - accuracy: 0.7850 - val_loss: 0.5786 - val_accuracy: 0.7985 - lr: 1.0000e-05
# Epoch 30/100
# 25/25 [==============================] - 7s 292ms/step - loss: 0.6258 - accuracy: 0.7625 - val_loss: 0.5752 - val_accuracy: 0.8000 - lr: 1.0000e-05
# Epoch 31/100
# 25/25 [==============================] - 7s 277ms/step - loss: 0.6143 - accuracy: 0.7875 - val_loss: 0.5733 - val_accuracy: 0.7998 - lr: 1.0000e-05
# Epoch 32/100
# 25/25 [==============================] - 7s 289ms/step - loss: 0.5736 - accuracy: 0.8112 - val_loss: 0.5698 - val_accuracy: 0.8027 - lr: 1.0000e-05
# Epoch 33/100
# 25/25 [==============================] - 7s 274ms/step - loss: 0.5954 - accuracy: 0.7937 - val_loss: 0.5675 - val_accuracy: 0.8031 - lr: 1.0000e-05
# Epoch 34/100
# 25/25 [==============================] - 7s 284ms/step - loss: 0.5686 - accuracy: 0.7975 - val_loss: 0.5684 - val_accuracy: 0.8009 - lr: 1.0000e-05
# Epoch 35/100
# 25/25 [==============================] - 7s 267ms/step - loss: 0.6024 - accuracy: 0.7937 - val_loss: 0.5627 - val_accuracy: 0.8051 - lr: 1.0000e-05
# Epoch 36/100
# 25/25 [==============================] - 7s 274ms/step - loss: 0.5777 - accuracy: 0.8175 - val_loss: 0.5627 - val_accuracy: 0.8051 - lr: 1.0000e-05
# Epoch 37/100
# 25/25 [==============================] - 7s 269ms/step - loss: 0.5886 - accuracy: 0.8012 - val_loss: 0.5617 - val_accuracy: 0.8058 - lr: 1.0000e-05
# Epoch 38/100
# 25/25 [==============================] - 7s 278ms/step - loss: 0.5961 - accuracy: 0.7937 - val_loss: 0.5595 - val_accuracy: 0.8059 - lr: 1.0000e-05
# Epoch 39/100
# 25/25 [==============================] - 6s 261ms/step - loss: 0.6030 - accuracy: 0.7975 - val_loss: 0.5579 - val_accuracy: 0.8077 - lr: 1.0000e-05
# Epoch 40/100
# 25/25 [==============================] - 7s 273ms/step - loss: 0.5559 - accuracy: 0.8150 - val_loss: 0.5564 - val_accuracy: 0.8070 - lr: 1.0000e-05
# Epoch 41/100
# 25/25 [==============================] - 7s 272ms/step - loss: 0.6064 - accuracy: 0.7875 - val_loss: 0.5548 - val_accuracy: 0.8062 - lr: 1.0000e-05
# Epoch 42/100
# 25/25 [==============================] - 7s 276ms/step - loss: 0.5536 - accuracy: 0.8288 - val_loss: 0.5552 - val_accuracy: 0.8081 - lr: 1.0000e-05
# Epoch 43/100
# 25/25 [==============================] - 6s 264ms/step - loss: 0.5458 - accuracy: 0.8175 - val_loss: 0.5530 - val_accuracy: 0.8078 - lr: 1.0000e-05
# Epoch 44/100
# 25/25 [==============================] - 7s 272ms/step - loss: 0.6019 - accuracy: 0.7875 - val_loss: 0.5519 - val_accuracy: 0.8113 - lr: 1.0000e-05
# Epoch 45/100
# 25/25 [==============================] - 6s 263ms/step - loss: 0.5692 - accuracy: 0.8062 - val_loss: 0.5489 - val_accuracy: 0.8102 - lr: 1.0000e-05
# Epoch 46/100
# 25/25 [==============================] - 7s 274ms/step - loss: 0.5753 - accuracy: 0.8175 - val_loss: 0.5502 - val_accuracy: 0.8106 - lr: 1.0000e-05
# Epoch 47/100
# 25/25 [==============================] - 6s 261ms/step - loss: 0.5449 - accuracy: 0.8300 - val_loss: 0.5456 - val_accuracy: 0.8140 - lr: 1.0000e-05
# Epoch 48/100
# 25/25 [==============================] - 7s 273ms/step - loss: 0.5647 - accuracy: 0.8062 - val_loss: 0.5414 - val_accuracy: 0.8132 - lr: 1.0000e-05
# Epoch 49/100
# 25/25 [==============================] - 7s 271ms/step - loss: 0.5925 - accuracy: 0.7987 - val_loss: 0.5381 - val_accuracy: 0.8137 - lr: 1.0000e-05
# Epoch 50/100
# 25/25 [==============================] - 7s 282ms/step - loss: 0.5780 - accuracy: 0.8062 - val_loss: 0.5408 - val_accuracy: 0.8148 - lr: 1.0000e-05
# Epoch 51/100
# 25/25 [==============================] - 7s 275ms/step - loss: 0.5727 - accuracy: 0.8238 - val_loss: 0.5374 - val_accuracy: 0.8178 - lr: 1.0000e-05
# Epoch 52/100
# 25/25 [==============================] - 7s 279ms/step - loss: 0.5700 - accuracy: 0.8062 - val_loss: 0.5371 - val_accuracy: 0.8175 - lr: 1.0000e-05
# Epoch 53/100
# 25/25 [==============================] - 6s 263ms/step - loss: 0.5838 - accuracy: 0.8062 - val_loss: 0.5362 - val_accuracy: 0.8172 - lr: 1.0000e-05
# Epoch 54/100
# 25/25 [==============================] - 7s 274ms/step - loss: 0.5768 - accuracy: 0.8025 - val_loss: 0.5379 - val_accuracy: 0.8179 - lr: 1.0000e-05
# Epoch 55/100
# 25/25 [==============================] - 6s 262ms/step - loss: 0.5607 - accuracy: 0.8125 - val_loss: 0.5352 - val_accuracy: 0.8191 - lr: 1.0000e-05
# Epoch 56/100
# 25/25 [==============================] - 6s 264ms/step - loss: 0.5900 - accuracy: 0.7962 - val_loss: 0.5341 - val_accuracy: 0.8206 - lr: 1.0000e-05
# Epoch 57/100
# 25/25 [==============================] - 6s 266ms/step - loss: 0.5849 - accuracy: 0.8087 - val_loss: 0.5335 - val_accuracy: 0.8194 - lr: 1.0000e-05
# Epoch 58/100
# 25/25 [==============================] - 6s 267ms/step - loss: 0.5323 - accuracy: 0.8313 - val_loss: 0.5311 - val_accuracy: 0.8202 - lr: 1.0000e-05
# Epoch 59/100
# 25/25 [==============================] - 6s 263ms/step - loss: 0.5489 - accuracy: 0.8125 - val_loss: 0.5288 - val_accuracy: 0.8199 - lr: 1.0000e-05
# Epoch 60/100
# 25/25 [==============================] - 7s 275ms/step - loss: 0.5285 - accuracy: 0.8280 - val_loss: 0.5273 - val_accuracy: 0.8228 - lr: 1.0000e-05
# Epoch 61/100
# 25/25 [==============================] - 6s 264ms/step - loss: 0.5532 - accuracy: 0.8200 - val_loss: 0.5321 - val_accuracy: 0.8233 - lr: 1.0000e-05
# Epoch 62/100
# 25/25 [==============================] - 7s 273ms/step - loss: 0.5698 - accuracy: 0.8100 - val_loss: 0.5271 - val_accuracy: 0.8253 - lr: 1.0000e-05
# Epoch 63/100
# 25/25 [==============================] - 6s 264ms/step - loss: 0.5584 - accuracy: 0.8062 - val_loss: 0.5230 - val_accuracy: 0.8246 - lr: 1.0000e-05
# Epoch 64/100
# 25/25 [==============================] - 6s 263ms/step - loss: 0.5345 - accuracy: 0.8318 - val_loss: 0.5228 - val_accuracy: 0.8248 - lr: 1.0000e-05
# Epoch 65/100
# 25/25 [==============================] - 6s 263ms/step - loss: 0.5440 - accuracy: 0.8213 - val_loss: 0.5264 - val_accuracy: 0.8252 - lr: 1.0000e-05
# Epoch 66/100
# 25/25 [==============================] - 7s 276ms/step - loss: 0.5310 - accuracy: 0.8325 - val_loss: 0.5279 - val_accuracy: 0.8253 - lr: 1.0000e-05
# Epoch 67/100
# 25/25 [==============================] - 6s 262ms/step - loss: 0.5743 - accuracy: 0.8138 - val_loss: 0.5264 - val_accuracy: 0.8223 - lr: 1.0000e-05
# Epoch 68/100
# 25/25 [==============================] - 7s 271ms/step - loss: 0.5693 - accuracy: 0.8062 - val_loss: 0.5249 - val_accuracy: 0.8232 - lr: 1.0000e-05
# Epoch 69/100
# 25/25 [==============================] - 6s 261ms/step - loss: 0.5620 - accuracy: 0.8188 - val_loss: 0.5213 - val_accuracy: 0.8246 - lr: 1.0000e-05
# Epoch 70/100
# 25/25 [==============================] - 7s 268ms/step - loss: 0.5771 - accuracy: 0.8125 - val_loss: 0.5185 - val_accuracy: 0.8277 - lr: 1.0000e-05
# Epoch 71/100
# 25/25 [==============================] - 6s 258ms/step - loss: 0.5622 - accuracy: 0.8175 - val_loss: 0.5196 - val_accuracy: 0.8280 - lr: 1.0000e-05
# Epoch 72/100
# 25/25 [==============================] - 6s 265ms/step - loss: 0.5172 - accuracy: 0.8475 - val_loss: 0.5205 - val_accuracy: 0.8298 - lr: 1.0000e-05
# Epoch 73/100
# 25/25 [==============================] - 6s 263ms/step - loss: 0.5243 - accuracy: 0.8413 - val_loss: 0.5195 - val_accuracy: 0.8310 - lr: 1.0000e-05
# Epoch 74/100
# 25/25 [==============================] - 7s 270ms/step - loss: 0.5509 - accuracy: 0.8075 - val_loss: 0.5220 - val_accuracy: 0.8298 - lr: 1.0000e-05
# Epoch 75/100
# 25/25 [==============================] - 6s 267ms/step - loss: 0.5432 - accuracy: 0.8213 - val_loss: 0.5148 - val_accuracy: 0.8323 - lr: 1.0000e-05
# Epoch 76/100
# 25/25 [==============================] - 7s 268ms/step - loss: 0.5458 - accuracy: 0.8250 - val_loss: 0.5160 - val_accuracy: 0.8284 - lr: 1.0000e-05
# Epoch 77/100
# 25/25 [==============================] - 6s 261ms/step - loss: 0.5471 - accuracy: 0.8388 - val_loss: 0.5145 - val_accuracy: 0.8321 - lr: 1.0000e-05
# Epoch 78/100
# 25/25 [==============================] - 7s 271ms/step - loss: 0.5210 - accuracy: 0.8400 - val_loss: 0.5130 - val_accuracy: 0.8334 - lr: 1.0000e-05
# Epoch 79/100
# 25/25 [==============================] - 6s 260ms/step - loss: 0.5385 - accuracy: 0.8238 - val_loss: 0.5130 - val_accuracy: 0.8330 - lr: 1.0000e-05
# Epoch 80/100
# 25/25 [==============================] - 6s 264ms/step - loss: 0.5411 - accuracy: 0.8363 - val_loss: 0.5141 - val_accuracy: 0.8331 - lr: 1.0000e-05
# Epoch 81/100
# 25/25 [==============================] - 6s 259ms/step - loss: 0.5497 - accuracy: 0.8313 - val_loss: 0.5136 - val_accuracy: 0.8347 - lr: 1.0000e-05
# Epoch 82/100
# 25/25 [==============================] - 6s 265ms/step - loss: 0.5522 - accuracy: 0.8263 - val_loss: 0.5170 - val_accuracy: 0.8353 - lr: 1.0000e-05
# Epoch 83/100
# 25/25 [==============================] - 6s 262ms/step - loss: 0.5715 - accuracy: 0.7987 - val_loss: 0.5062 - val_accuracy: 0.8347 - lr: 1.0000e-05
# Epoch 84/100
# 25/25 [==============================] - 6s 264ms/step - loss: 0.5467 - accuracy: 0.8313 - val_loss: 0.5058 - val_accuracy: 0.8347 - lr: 1.0000e-05
# Epoch 85/100
# 25/25 [==============================] - 6s 261ms/step - loss: 0.4883 - accuracy: 0.8487 - val_loss: 0.5047 - val_accuracy: 0.8347 - lr: 1.0000e-05
# Epoch 86/100
# 25/25 [==============================] - 6s 262ms/step - loss: 0.5351 - accuracy: 0.8363 - val_loss: 0.5026 - val_accuracy: 0.8370 - lr: 1.0000e-05
# Epoch 87/100
# 25/25 [==============================] - 6s 261ms/step - loss: 0.5485 - accuracy: 0.8125 - val_loss: 0.5083 - val_accuracy: 0.8387 - lr: 1.0000e-05
# Epoch 88/100
# 25/25 [==============================] - 6s 262ms/step - loss: 0.5181 - accuracy: 0.8250 - val_loss: 0.5079 - val_accuracy: 0.8383 - lr: 1.0000e-05
# Epoch 89/100
# 25/25 [==============================] - 6s 259ms/step - loss: 0.5414 - accuracy: 0.8188 - val_loss: 0.5129 - val_accuracy: 0.8380 - lr: 1.0000e-05
# Epoch 90/100
# 25/25 [==============================] - 6s 264ms/step - loss: 0.5362 - accuracy: 0.8263 - val_loss: 0.5036 - val_accuracy: 0.8358 - lr: 1.0000e-05
# Epoch 91/100
# 25/25 [==============================] - 6s 257ms/step - loss: 0.5473 - accuracy: 0.8175 - val_loss: 0.5020 - val_accuracy: 0.8370 - lr: 1.0000e-05
# Epoch 92/100
# 25/25 [==============================] - 6s 261ms/step - loss: 0.5477 - accuracy: 0.8163 - val_loss: 0.5081 - val_accuracy: 0.8395 - lr: 1.0000e-05
# Epoch 93/100
# 25/25 [==============================] - 6s 258ms/step - loss: 0.5253 - accuracy: 0.8213 - val_loss: 0.5029 - val_accuracy: 0.8392 - lr: 1.0000e-05
# Epoch 94/100
# 25/25 [==============================] - 7s 268ms/step - loss: 0.5183 - accuracy: 0.8413 - val_loss: 0.4981 - val_accuracy: 0.8385 - lr: 1.0000e-05
# Epoch 95/100
# 25/25 [==============================] - 6s 258ms/step - loss: 0.5447 - accuracy: 0.8238 - val_loss: 0.5013 - val_accuracy: 0.8387 - lr: 1.0000e-05
# Epoch 96/100
# 25/25 [==============================] - 6s 261ms/step - loss: 0.5304 - accuracy: 0.8313 - val_loss: 0.5067 - val_accuracy: 0.8372 - lr: 1.0000e-05
# Epoch 97/100
# 25/25 [==============================] - 6s 258ms/step - loss: 0.5294 - accuracy: 0.8400 - val_loss: 0.4992 - val_accuracy: 0.8414 - lr: 1.0000e-05
# Epoch 98/100
# 25/25 [==============================] - 7s 269ms/step - loss: 0.5261 - accuracy: 0.8288 - val_loss: 0.4970 - val_accuracy: 0.8389 - lr: 1.0000e-05
# Epoch 99/100
# 25/25 [==============================] - 6s 257ms/step - loss: 0.5133 - accuracy: 0.8388 - val_loss: 0.4978 - val_accuracy: 0.8392 - lr: 1.0000e-05
# Epoch 100/100
# 25/25 [==============================] - 6s 262ms/step - loss: 0.5143 - accuracy: 0.8375 - val_loss: 0.5023 - val_accuracy: 0.8354 - lr: 1.0000e-05
# 232/232 [==============================] - 6s 24ms/step - loss: 0.5023 - accuracy: 0.8354
#
# Model's Evaluation Metrics:
# ---------------------------
# Accuracy: 83.54 %
# Loss: 50.23 %

# %% [markdown]
# # Model Accuracy

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.xlim([0, epochs])
plt.ylim([0, 1])
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# # Model Loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.xlim([0, epochs])
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# serialize model to JSON
model_json = model.to_json()
with open("modeltemp/model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("modeltemp/model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# # CONFUSION MATRIX

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
batch_size = 3459
test_datagen = ImageDataGenerator(rescale= 1./255)
# Generator for test data
print("\ntest_generator")
test_generator = test_datagen.flow_from_directory('dataset3/test/', 
                                                        target_size = (160, 160),
                                                        batch_size = batch_size,
                                                        class_mode = 'sparse')
# Out:
# test_generator
# Found 3459 images belonging to 4 classes.

# %%
from tqdm import tqdm
import pandas as pd
import matplotlib.pyplot as plt
correct_prediction = pd.DataFrame(columns=['ImageArray', 'Actual_label', 'Predicted_label','Target'])
false_prediction = pd.DataFrame(columns=['ImageArray', 'Actual_label', 'Predicted_label','Target'])
class_names = {0 : 'CONFUSED', 1 : 'DELIGHT', 2 : 'FRUSTRATED', 3 : 'NEUTRAL'}
pred = []
# predict first 9 images in Test image
plt.figure(figsize=(12, 14))
images, actlabel = test_generator.next()
for i in range(len(test_generator)):
    with tf.device('gpu:0'):
        predict_x=emotion_model.predict(images) 
    labels=np.argmax(predict_x,axis=1)
    for j in tqdm(range(len(labels))):
        pred.append(labels[j])
        if class_names[labels[j]] == class_names[actlabel[j]]:
            correct_prediction = correct_prediction.append({'ImageArray': (images[j]), 'Actual_label': (class_names[actlabel[j]]), 'Predicted_label': (class_names[labels[j]]), 'Target': 'True'}, ignore_index=True)
        else:
            false_prediction = false_prediction.append({'ImageArray': (images[j]), 'Actual_label': (class_names[actlabel[j]]), 'Predicted_label': (class_names[labels[j]]), 'Target': 'False'}, ignore_index=True)
# Out:
# 109/109 [==============================] - 1s 10ms/step
# 100%|██████████| 3459/3459 [00:05<00:00, 597.01it/s]

# %%
import cv2
import numpy as np
#from keras.models import model_from_json
from PIL import Image
from tqdm import tqdm
import shutil

import tensorflow as tf


config = tf.compat.v1.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.2 ##
config.gpu_options.allow_growth=False # True
sess = tf.compat.v1.Session(config=config)

tf.compat.v1.keras.backend.set_session(sess)
from tensorflow.compat.v1.keras.models import model_from_json


emotion_dict = {0 : 'CONFUSED', 1 : 'DELIGHT', 2 : 'FRUSTRATED', 3 : 'NEUTRAL'}

# load json and create model
json_file = open('modeltemp/model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
emotion_model = model_from_json(loaded_model_json)

# load weights into new model
emotion_model.load_weights("modeltemp/model.h5")
print("Loaded model from disk")

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

y_pred = np.array(pred)
y_test = np.array(actlabel)
labels = ['CONFUSED', 'DELIGHT', 'FRUSTRATED', 'NEUTRAL']

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)


fig, ax = plt.subplots(figsize=(10,10))
disp.plot(ax=ax,cmap=plt.cm.Blues)
